# %%
"""Feene debe quitar los resultados repetidos"""

import pandas as pd
import sys

# %%
# Pregunta por la ubicación del archivo a convertir
infile = input("File's absolute path:")

data = pd.read_table(infile, header=None)
data
# Out:
# File's absolute path:/home/raulrosas/Documentos/IFC/lab/filter_lab/maze_complete.csv
#                    0                           1              2  \
# 0     XP_037509155.1  msaprobs_alignment_4742434   0.000000e+00
# 1     XP_037509155.1  msaprobs_alignment_4742434   0.000000e+00
# 2     XP_026880781.2  msaprobs_alignment_4742434   0.000000e+00
# 3     XP_026880781.2  msaprobs_alignment_4742434   0.000000e+00
# 4     XP_043656733.1  msaprobs_alignment_4742434  2.200000e-259
# ...              ...                         ...            ...
# 2189  NP_001248421.1  msaprobs_alignment_4742434   9.000000e+00
# 2190  XP_005556090.1  msaprobs_alignment_4742434   9.000000e+00
# 2191  XP_017917076.1  msaprobs_alignment_4742434   9.300000e+00
# 2192  XP_024909188.1  msaprobs_alignment_4742434   9.700000e+00
# 2193  XP_037871049.1  msaprobs_alignment_4742434   9.900000e+00
#
#                   3              4  \
# 0     3.600000e-189  2.200000e-185
# 1     6.100000e-156  3.700000e-152
# 2     2.800000e-170  1.700000e-166
# 3     4.700000e-167  2.800000e-163
# 4     2.600000e-262  1.600000e-258
# ...             ...            ...
# 2189   2.100000e-03   1.300000e+01
# 2190   2.100000e-03   1.300000e+01
# 2191   1.700000e-03   1.000000e+01
# 2192   2.000000e-03   1.200000e+01
# 2193   2.000000e-03   1.200000e+01
#
#                                                       5
# 0     LOW QUALITY PROTEIN: chitin synthase chs-1-lik...
# 1     LOW QUALITY PROTEIN: chitin synthase chs-1-lik...
# 2     LOW QUALITY PROTEIN: chitin synthase 1 [Electr...
# 3     LOW QUALITY PROTEIN: chitin synthase 1 [Electr...
# 4     chitin synthase chs-2 isoform X1 [Drosophila t...
# ...                                                 ...
# 2189   endothelin-1 receptor precursor [Macaca mulatta]
# 2190  PREDICTED: endothelin-1 receptor isoform X1 [M...
# 2191  PREDICTED: endothelin-1 receptor isoform X2 [C...
# 2192  granzyme A-like  partial [Cynoglossus semilaevis]
# 2193  gamma-aminobutyric acid receptor subunit beta-...
#
# [2194 rows x 6 columns]

# %%
data_inicial=len(data)
print("Tus resultados iniciales totales son:", data_inicial)
# Out:
# Tus resultados iniciales totales son: 2194

# %%
pure_data = data.drop_duplicates(subset=5,keep='first')

# %%
pure_data
# Out:
#                    0                           1              2  \
# 0     XP_037509155.1  msaprobs_alignment_4742434   0.000000e+00
# 2     XP_026880781.2  msaprobs_alignment_4742434   0.000000e+00
# 4     XP_043656733.1  msaprobs_alignment_4742434  2.200000e-259
# 6     XP_039495856.1  msaprobs_alignment_4742434  2.800000e-259
# 7     XP_033162000.1  msaprobs_alignment_4742434  4.200000e-259
# ...              ...                         ...            ...
# 2189  NP_001248421.1  msaprobs_alignment_4742434   9.000000e+00
# 2190  XP_005556090.1  msaprobs_alignment_4742434   9.000000e+00
# 2191  XP_017917076.1  msaprobs_alignment_4742434   9.300000e+00
# 2192  XP_024909188.1  msaprobs_alignment_4742434   9.700000e+00
# 2193  XP_037871049.1  msaprobs_alignment_4742434   9.900000e+00
#
#                   3              4  \
# 0     3.600000e-189  2.200000e-185
# 2     2.800000e-170  1.700000e-166
# 4     2.600000e-262  1.600000e-258
# 6     2.200000e-262  1.400000e-258
# 7     3.200000e-262  1.900000e-258
# ...             ...            ...
# 2189   2.100000e-03   1.300000e+01
# 2190   2.100000e-03   1.300000e+01
# 2191   1.700000e-03   1.000000e+01
# 2192   2.000000e-03   1.200000e+01
# 2193   2.000000e-03   1.200000e+01
#
#                                                       5
# 0     LOW QUALITY PROTEIN: chitin synthase chs-1-lik...
# 2     LOW QUALITY PROTEIN: chitin synthase 1 [Electr...
# 4     chitin synthase chs-2 isoform X1 [Drosophila t...
# 6     chitin synthase chs-2 isoform X2 [Drosophila s...
# 7     chitin synthase chs-2 isoform X3 [Drosophila m...
# ...                                                 ...
# 2189   endothelin-1 receptor precursor [Macaca mulatta]
# 2190  PREDICTED: endothelin-1 receptor isoform X1 [M...
# 2191  PREDICTED: endothelin-1 receptor isoform X2 [C...
# 2192  granzyme A-like  partial [Cynoglossus semilaevis]
# 2193  gamma-aminobutyric acid receptor subunit beta-...
#
# [1436 rows x 6 columns]

# %%
pure_data.to_csv('feene.csv', index=False, header=False, sep='\t')

data_final = len(pure_data)
print("Tus resultados finales son:", data_final, "Están en el archivo feene.csv dentro de el mismo directorio que este script!")
# Out:
# Tus resultados finales son: 1436 Están en el archivo feene.csv dentro de el mismo directorio que este script!
