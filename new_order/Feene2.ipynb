# %%
"""Feene debe quitar los resultados repetidos"""

import pandas as pd
import sys

# %%
# Pregunta por la ubicación del archivo a convertir
infile = input("File's absolute path:")

data = pd.read_table(infile, header=None)
data

# /home/raulrosas/Documentos/IFC/lab/filter_lab/clean_start/new_order
# Out:
# File's absolute path:/home/raulrosas/Documentos/IFC/lab/filter_lab/clean_start/new_order/PLAC_gtf_saple.csv
#                  0          1               2               3  \
# 0             chs1  113586674  XM_027024980.2  XP_026880781.2
# 1             chs1  113586674  XM_027024980.2  XP_026880781.2
# 2             chs1  113586674  XM_027024980.2  XP_026880781.2
# 3             chs1  113586674  XM_027024980.2  XP_026880781.2
# 4     LOC105330644  105330644  XM_034448352.1  XP_034304243.1
# ...            ...        ...             ...             ...
# 3317  LOC117869887  117869887  XM_034756991.1  XP_034612882.1
# 3318          Has3  116070107  XM_031341312.1  XP_031197172.1
# 3319          Has3  116070107  XM_031341312.1  XP_031197172.1
# 3320  LOC118760849  118760849  XM_036500002.1  XP_036355895.1
# 3321  LOC115230150  115230150  XM_029800362.2  XP_029656222.2
#
#                                                 4
# 0            GCF_013358815.1_fEleEle1.pri_genomic
# 1            GCF_013358815.1_fEleEle1.pri_genomic
# 2            GCF_013358815.1_fEleEle1.pri_genomic
# 3            GCF_013358815.1_fEleEle1.pri_genomic
# 4     GCF_902806645.1_cgigas_uk_roslin_v1_genomic
# ...                                           ...
# 3317          GCF_013100865.1_CAS_Tse_1.0_genomic
# 3318          GCF_008632895.1_UCSF_Mcou_1_genomic
# 3319          GCF_008632895.1_UCSF_Mcou_1_genomic
# 3320          GCF_006345805.1_ASM634580v1_genomic
# 3321          GCF_006345805.1_ASM634580v1_genomic
#
# [3322 rows x 5 columns]

# %%
data_inicial=len(data)
print("Tus resultados iniciales totales son:", data_inicial)
# Out:
# Tus resultados iniciales totales son: 3322

# %%
pure_data = data.drop_duplicates(subset=1,keep='first')

# %%
pure_data
# Out:
#                  0          1               2               3  \
# 0             chs1  113586674  XM_027024980.2  XP_026880781.2
# 4     LOC105330644  105330644  XM_034448352.1  XP_034304243.1
# 10    LOC122844036  122844036  XM_044139240.1  XP_043995175.1
# 12    LOC111106230  111106230  XM_022440818.1  XP_022296526.1
# 14    LOC111105812  111105812  XM_022440212.1  XP_022295920.1
# ...            ...        ...             ...             ...
# 3310  LOC111128180  111128180  XM_022473658.1  XP_022329366.1
# 3311  LOC116659727  116659727  XM_032467552.1  XP_032323443.1
# 3317  LOC117869887  117869887  XM_034756991.1  XP_034612882.1
# 3320  LOC118760849  118760849  XM_036500002.1  XP_036355895.1
# 3321  LOC115230150  115230150  XM_029800362.2  XP_029656222.2
#
#                                                 4
# 0            GCF_013358815.1_fEleEle1.pri_genomic
# 4     GCF_902806645.1_cgigas_uk_roslin_v1_genomic
# 10           GCF_019740435.1_SWU_Gaff_1.0_genomic
# 12        GCF_002022765.2_C_virginica-3.0_genomic
# 14        GCF_002022765.2_C_virginica-3.0_genomic
# ...                                           ...
# 3310      GCF_002022765.2_C_virginica-3.0_genomic
# 3311      GCF_009834535.1_BCGSAC_Cfer_1.0_genomic
# 3317          GCF_013100865.1_CAS_Tse_1.0_genomic
# 3320          GCF_006345805.1_ASM634580v1_genomic
# 3321          GCF_006345805.1_ASM634580v1_genomic
#
# [1093 rows x 5 columns]

# %%
pure_data.to_csv('feene.csv', index=False, header=False, sep='\t')

data_final = len(pure_data)
print("Tus resultados finales son:", data_final, "Están en el archivo feene.csv dentro de el mismo directorio que este script!")
# Out:
# Tus resultados finales son: 1093 Están en el archivo feene.csv dentro de el mismo directorio que este script!
